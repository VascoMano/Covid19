# %% [markdown]
# # Teste
# > bla bla bla
#
# - toc: true- branch: master- badges: true
# - comments: true
# - author: VascoMano
# - categories: [Covid, jupyter]

# %% [markdown]
# This is just a test...
