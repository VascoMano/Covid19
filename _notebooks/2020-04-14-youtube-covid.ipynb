# %% [markdown]
# # Race Bar Chart - Covid 19

# %%
#hide_input
from IPython.lib.display import YouTubeVideo
YouTubeVideo('N-g20Cha6Sk')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/N-g20Cha6Sk"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
